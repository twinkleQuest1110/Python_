# %%
name ='Ishu'

# %%
name
# Out:
# 'Ishu'

# %%
name.upper()
# Out:
# 'ISHU'

# %%
name.endswith("hu")
# Out:
# True

# %%
name.endswith("is")
# Out:
# False

# %%
name.lower()
# Out:
# 'ishu'

# %%
name.count("s")
# Out:
# 1

# %%
print(len(name))
# Out:
# 4

# %%
movie = "Jurasic Park"
print(len(movie))
# Out:
# 12

# %%
movie[0:5]
# Out:
# 'Juras'

# %%
movie[1:5]
# Out:
# 'uras'

# %%
movie[0:8]
# Out:
# 'Jurasic '

# %%
movie[1:-1]  # Negative indexes
# Out:
# 'urasic Par'

# %%
movie[1:11]  # this is happen by 1 {aaisa ka aaisa then (length+(-1)= 12-1=11
# Out:
# 'urasic Par'

# %%
movie[-10:-3]  #[12-10:12-3] = [2:9]
# Out:
# 'rasic P'
