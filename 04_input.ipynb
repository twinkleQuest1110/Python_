# %%
a = input("Enter value of a:")
# Out:
# Enter value of a: 12

# %%
a
# Out:
# '12'

# %%
b = input("Enter valur of b:")
# Out:
# Enter valur of b: 12

# %%
b
# Out:
# '12'

# %%
a+b
# Out:
# '1212'

# %%
int(a) + int (b)
# Out:
# 24

# %%
c=input()
# Out:
#  45

# %%
c
# Out:
# '45'
