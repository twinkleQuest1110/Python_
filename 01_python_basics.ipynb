# %%
a=5

# %%
b = 32

# %%
a+b
# Out:
# 37

# %%
name= "Twinkle"

# %%
print("Hello Iisha") #This print "....."  this on screen
# Out:
# Hello Iisha

# %% [markdown]
# This is use instead of comment commonly

# %%
print(type(a))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
type(name)  # this is feaature of Jypnb
# Out:
# str

# %%
a = "58"

# %%
b = "122"

# %%
print(a+b) #String concinated
# Out:
# 58122

# %%
int(a)+int(b) # TypeCasting
# Out:
# 180
